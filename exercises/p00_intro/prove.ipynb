# %%
import numpy as np
import random

# %%
a = np.array([1,2,3])
b = np.matrix([[1],[2],[3]])
c = np.matrix([[1,4],[2,5],[3,6]])

c = np.array([[[[0], [1], [2], [3]]]])


print(c)

# print((a * (b+c)).sum())
# Out:
# [[[[0]
#    [1]
#    [2]
#    [3]]]]

# %%
directions = np.array([
            [-1,0], #UP
            [0,-1], #LEFT
            [1,0], #DOWN
            [0,1] #RIGHT
        ])
print(directions[0])
# Out:
# [-1  0]

# %%
obstacles = np.zeros((2, 3))
for i in range(2):
    obstacles[ random.randrange(2) , random.randrange(3)] = 1
print(obstacles)
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]]

# %%
c = np.array([[1,4],[2,3]])
print(c.shape)
# Out:
# (2, 2)

# %%
print(np.inf)
# Out:
# inf
