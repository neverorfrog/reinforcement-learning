# %%
import numpy as np

a = np.array([1,2,3])
b = np.matrix([[1],[2],[3]])
c = np.matrix([[1,4],[2,5],[3,6]])


print(b+c)

print((a * (b+c)).sum())
# Out:
# [[2 5]
#  [4 7]
#  [6 9]]
# 74
# [[12 30]
#  [24 42]
#  [36 54]]
