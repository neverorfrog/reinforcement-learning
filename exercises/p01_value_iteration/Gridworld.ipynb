# %% [markdown]
# # Second practical exercise: Grid World and Value iteration

# %% [markdown]
# # A deterministic grid world

# %% [markdown]
# Finite grid with some obstacles inside. The agent can move up, left, right and down.

# %% [markdown]
# ![](imgs/grid_world.png)

# %%
#import
import gym
import numpy as np
from gym import spaces
import random

# %%
# custom 2d grid world enviroment
class GridWorld(gym.Env):
    metadata = {'render.modes': ['console']}

    
    # actions available
    UP = 0
    LEFT = 1
    DOWN = 2
    RIGHT = 3


    def __init__(self, width, height):
        super(GridWorld, self).__init__()
        self.ACTION_NAMES = ["UP", "LEFT", "DOWN", "RIGHT"]
        self.num_actions = 4

        self.size = width * height  # size of the grid world
        self.num_states = self.size
        self.width = width
        self.height = height
        self.num_obstacles = int((width+height)/2)
        self.end_state = np.array([height - 1, width - 1], dtype=np.uint8) # goal state = bottom right cell

        # actions of agents : up, down, left and right
        self.action_space = spaces.Discrete(4)
        # observation : cell indices in the grid
        self.observation_space = spaces.MultiDiscrete([self.height, self.width])

        self.obstacles = np.zeros((height, width))

        for i in range(self.num_obstacles):
            self.obstacles[ random.randrange(height) , random.randrange(width)] = 1

        self.num_steps = 0
        self.max_steps = height*width

        self.current_state = np.zeros((2), np.uint8)#init state = [0,0]

        self.directions = np.array([
            [-1,0], #UP
            [0,-1], #LEFT
            [1,0], #DOWN
            [0,1] #RIGHT
        ])
        print(self.directions[1])
        
    def step(self, action):
        s_prime = self.transition_function(self.current_state, action)
        reward = self.reward_function(s_prime)
        done = self.termination_condition(s_prime)

        self.current_state = s_prime
        self.num_steps += 1

        return self.current_state, reward, done, None
    
    
    def transition_function(self, s, a):
        s_prime = s

        s_prime_temp = s + self.directions[a]
        if s_prime_temp[0] >= 0 and s_prime_temp[1] >= 0 and s_prime_temp[0] < self.width and s_prime_temp[1] < self.height:
            s_prime = s_prime_temp
        
        return s_prime
    
    
    def reward_function(self,s):
        if s[0] != self.end_state[0] and s[1] != self.end_state[1]:
            r = 1/(self.end_state - s)
        else:
             r = 1
        return r;
    
    def termination_condition(self, s):
        done = False

        infinalstate = self.current_state[0] == self.end_state[0] && self.current_state[1] == self.end_state[1];
        done = self.num_steps > self.max_steps or infinalstate;

        return done
    
    def reset(self):
        self.current_state = np.zeros((2), np.uint8)

        return self.current_state
    
    def render(self):
        '''
            render the state
        '''

        row = self.current_state[0]
        col = self.current_state[1]

        for r in range(self.height):
            for c in range(self.width):
                if r == row and c == col:
                    print("| A ", end='')
                elif r == self.end_state[0] and c == self.end_state[1]:
                    print("| G ", end='')
                else:
                    if self.obstacles[r,c] == 1:
                        print('|///', end='')
                    else:
                        print('|___', end='')
            print('|')
        print('\n')

# %% [markdown]
# Simulate all the four actions

# %%
env = GridWorld(3,5)
env.reset()
env.render()

action_sequence = [3,1]

for a in action_sequence:
    env.step(a)
    env.render()
# Out:
# [ 0 -1]
# | A |///|___|
# |///|___|___|
# |___|___|___|
# |___|___|___|
# |___|___| G |
#
#
# |___| A |___|
# |///|___|___|
# |___|___|___|
# |___|___|___|
# |___|___| G |
#
#
# | A |///|___|
# |///|___|___|
# |___|___|___|
# |___|___|___|
# |___|___| G |

# %% [markdown]
# Simulate a random episode

# %%
done = False
while not done:
    action = env.action_space.sample()
    print(env.ACTION_NAMES[action])
    state, reward, done, _ = env.step(action)
    env.render()
# Out:
# DOWN
# |___|___|///|
# |///|///|___|
# |___| A |///|
# |___|___|___|
# |___|___| G |
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [37], line 2
#       1 done = False
# ----> 2 while not done:
#       3     action = env.action_space.sample()
#       4     print(env.ACTION_NAMES[action])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## A non deterministic grid world

# %% [markdown]
# The agent goes with probability p to the right cell, with probability 1 - p in a different cell

# %%
class NonDeterministicGridWorld(GridWorld):
    def __init__(self, width, height, p=0.8):
        super(NonDeterministicGridWorld, self).__init__(width, height)
        self.probability_right_action = p

    def transition_function(self, s, a):
        s_prime = s + self.directions[a, :]

        #with probability 1 - p diagonal movement
        if random.random() <= 1 - self.probability_right_action:
            if random.random() < 0.5:
                s_prime = s_prime + self.directions[(a+1)%self.num_actions, :]
            else:
                s_prime = s_prime + self.directions[(a-1)%self.num_actions, :]


        if s_prime[0] < self.height and s_prime[1] < self.width and (s_prime >= 0).all():
            if self.obstacles[s_prime[0], s_prime[1]] == 0 :
                return s_prime

        return s

# %% [markdown]
# Simulate a random episode

# %%
env = NonDeterministicGridWorld(3,5)
env.reset()
env.render()
# Out:
# [ 0 -1]
# | A |___|///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |

# %%
done = False
while not done:
    action = env.action_space.sample()
    print(env.ACTION_NAMES[action])
    state, reward, done, _ = env.step(action)
    env.render()
# Out:
# LEFT
# | A |___|///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# UP
# | A |___|///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# DOWN
# | A |___|///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# RIGHT
# |___| A |///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# LEFT
# | A |___|///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# UP
# | A |___|///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# LEFT
# | A |___|///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# RIGHT
# |___| A |///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# RIGHT
# |___| A |///|
# |///|___|///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# DOWN
# |___|___|///|
# |///| A |///|
# |___|___|___|
# |___|___|///|
# |___|___| G |
#
#
# DOWN
# |___|___|///|
# |///|___|///|
# |___| A |___|
# |___|___|///|
# |___|___| G |
#
#
# LEFT
# |___|___|///|
# |///|___|///|
# | A |___|___|
# |___|___|///|
# |___|___| G |
#
#
# UP
# |___|___|///|
# |///|___|///|
# | A |___|___|
# |___|___|///|
# |___|___| G |
#
#
# UP
# |___|___|///|
# |///|___|///|
# | A |___|___|
# |___|___|///|
# |___|___| G |
#
#
# LEFT
# |___|___|///|
# |///|___|///|
# | A |___|___|
# |___|___|///|
# |___|___| G |
#
#
# UP
# |___|___|///|
# |///|___|///|
# | A |___|___|
# |___|___|///|
# |___|___| G |
#
#
# DOWN
# |___|___|///|
# |///|___|///|
# |___|___|___|
# | A |___|///|
# |___|___| G |
