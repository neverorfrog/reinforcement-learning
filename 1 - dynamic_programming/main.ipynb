# %%
import sys
sys.path.insert(0,"..")
from policy_iteration import policy_iteration
from tools.gridworld import *
from tools.trainer import *

train(GridWorld, policy_iteration)
# Out:
# Starting game 1
# Optimal policy reached in 2 iterations
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# | A |///|___|
# |___|///|___|
# |///|///| G |
#
#
# 	Total Reward: 0.0
# Starting game 2
# Optimal policy reached in 0 iterations
# | A |___|___|///|
# |___|///|///|___|
# |///|___|___|___|
# |___|___|___| G |
#
#
# | A |___|___|///|
# |___|///|///|___|
# |///|___|___|___|
# |___|___|___| G |
#
#
# | A |___|___|///|
# |___|///|///|___|
# |///|___|___|___|
# ...
